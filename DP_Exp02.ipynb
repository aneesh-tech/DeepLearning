# %% [markdown]
# <a href="https://colab.research.google.com/github/aneesh-tech/DeepLearning/blob/main/DP_Exp02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

# Load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Convert to categorical
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build model
def build_model(activation_function='relu'):
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))
    model.add(Dense(512, activation=activation_function))
    model.add(Dense(512, activation=activation_function))
    model.add(Dense(10, activation='softmax'))
    return model

# Hyperparameters
activation_functions = ['relu', 'sigmoid', 'tanh']
optimizers = ['adam', 'sgd']

results = {}

# Training loop
for activation in activation_functions:
    for optimizer in optimizers:
        print("\nTraining with:", activation, optimizer)

        model = build_model(activation)
        model.compile(optimizer=optimizer,
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        history = model.fit(X_train, y_train,
                            epochs=10,
                            batch_size=64,
                            validation_data=(X_test, y_test),
                            verbose=0)

        loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

        results[(activation, optimizer)] = accuracy

        print("Accuracy:", accuracy)

# Find best model
best_model = max(results, key=results.get)

print("\nBest Model:")
print("Activation:", best_model[0])
print("Optimizer:", best_model[1])
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
#
# Training with: relu adam
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Accuracy: 0.48750001192092896
#
# Training with: relu sgd
# Accuracy: 0.46630001068115234
#
# Training with: sigmoid adam
# Accuracy: 0.4440999925136566
#
# Training with: sigmoid sgd
# Accuracy: 0.3255999982357025
#
# Training with: tanh adam
# Accuracy: 0.37439998984336853
#
# Training with: tanh sgd
# Accuracy: 0.4309999942779541
#
# Best Model:
# Activation: relu
# Optimizer: adam
